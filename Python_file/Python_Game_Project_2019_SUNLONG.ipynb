# %%
"""
Created on Tuesday Oct 17th 19:52:46 2019

@author: sunlong_ngouv 
"""

"""
  _  _______ _______ _____ _    _ ______ _   _           _____ ____  _   _ _______ ______  _____ _______ 
 | |/ |_   _|__   __/ ____| |  | |  ____| \ | |         / ____/ __ \| \ | |__   __|  ____|/ ____|__   __|
 | ' /  | |    | | | |    | |__| | |__  |  \| |        | |   | |  | |  \| |  | |  | |__  | (___    | |   
 |  <   | |    | | | |    |  __  |  __| | . ` |        | |   | |  | | . ` |  | |  |  __|  \___ \   | |   
 | . \ _| |_   | | | |____| |  | | |____| |\  |        | |___| |__| | |\  |  | |  | |____ ____) |  | |   
 |_|\_|_____|  |_|  \_____|_|  |_|______|_| \_|         \_____\____/|_| \_|  |_|  |______|_____/   |_|   
                                                                                                         
"""                                                                                                         
################################################################################################################
################################################################################################################
"""

    DocString:
    
    A) Introduction:
    This is 'Kitchen contest' game for all executive chefs. The game was structured 
    from easy to difficult degrees, consisting of selecting images, multiple-choice answers,
    mathematics and physics, relating to being a potential chef. There are 3 rounds:
        
    Round 1: Identify contestant's knowledge about various exotic foods through image recognition.(3pts)
    Round 2: Identify contestant's ability to make foods through choosing right ingredients.(3pts)
    Round 3: Quantify contestant's IQ with some logic questions.(10pts)
       
    B) Uncommon packages for this game:
    import cv2      : ENTER "pip install opencv-python" and then "import CV2"
    import pathlib  : ENTER "pip install pathlib"  
    
    C) Image files was enclosed in zip.
    
    D) Game time is around 3-4 minutes.
    
"""
################################################################################################################
################################################################################################################


# %matplotlib inline
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2
import matplotlib.pyplot as plt
import os
from pathlib import Path
from sys import exit
            

    
def start():
    
    # Warm up
    host_name = 'Shawn'
    #question_number1 = '3'
    print(f"""\033[1m
Welcome to 'KITCHEN CONTEST GAME'!!!
My name is {host_name}, your host for today game. Before we enter to the game,
may I know more about your?\033[0m""")
    
    contestant_name = input('\nWhat is your name?\n')
    contestant_country = input('\nWhich country are you from?\n')
    contestant_food = input('''\nWhich type of food do you like the most?
                        1) American Foods
                        2) European Foods
                        3) Asian Foods
                        
                        Please key in a number only!
                        \n''')

    print(f"""\033[1m
Nice to meet you {contestant_name} and glad to know you are from {contestant_country} and like 
type #{contestant_food} foods. You may be very exciting to start the game now. Have fun!!!\033[0m""")
    
    input("<Press enter to continue>")
    round_1()

############### ROUND 1 ###############
################################################################################################################        
def round_1(): 
    #Set up score per candidate
    global score
    score = 0
    
    # Instruction 1
    question_number2 = '3'
    
    print(f"""\033[1m
INSTRUCTION 1:
This is the first stage of the game. You are tested on your knowledge about exotic foods 
with {question_number2} questions. Each question has three images as choices, and you
should select one image corresponding to the questions. Let's try!
---3pts---\033[0m""")
    
    input("<Press enter to continue>\n")
    Q_1()
           
    #QUESTION 1
def Q_1():
    global score
    Q1 = '''
1) Which picture below is 'Spaghetti carbonara'?\n'''
    print(Q1)

    #Identify path of impages
    #path=r"C:\\Users\\DELL\\Documents\\PyGam\\"
    path=os.getcwd()
       
    #Pot Three images as multiple choices
    img_path1 = path + '\image_1.jpg'
    img_path2 = path + '\image_2.jpg'
    img_path3 = path + '\image_3.jpg'
    
    img1 = cv2.imread(img_path1,1)
    img2 = cv2.imread(img_path2,1)
    img3 = cv2.imread(img_path3,1)
    
    #Convert color of images
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
    
    title = ['A', 'B', 'C'] #put titles on the three pictures
    image = [img1,img2,img3]
    for i in range(3):
        plt.subplot(1,3,i+1)
        plt.imshow(image[i])
        plt.title(title[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
    #Print answer sheet
    answer = input('Please answer here:\t')
    print(answer)
    
    #Scoring conditions
    if answer == 'A' or answer == 'a':
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        Q_2()
    
    elif answer == 'B' or answer == 'b' or answer == 'C' or answer == 'c':
        print ("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        Q_2()
    
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        Q_1()


    #QUESTION 2
def Q_2():
    global score
    Q2 = '''
2) Which picture below is 'Tom Yum Clear Soup'?\n'''
    print(Q2)
    
    #Identify path of impages
    #path=r"C:\\Users\\DELL\\Documents\\PyGam\\"
    path=os.getcwd()
        
    #Pot Three images as multiple choices
    img_path4 = path + '\image_4.jpg'
    img_path5 = path + '\image_5.jpg'
    img_path6 = path + '\image_6.jpg'
    
    img4 = cv2.imread(img_path4,1)
    img5 = cv2.imread(img_path5,1)
    img6 = cv2.imread(img_path6,1)
    
    #Convert color of images
    img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)
    img5 = cv2.cvtColor(img5, cv2.COLOR_BGR2RGB)
    img6 = cv2.cvtColor(img6, cv2.COLOR_BGR2RGB)
    
    title = ['A', 'B', 'C'] #put titles on the three pictures
    image = [img4,img5,img6]
    for i in range(3):
        plt.subplot(1,3,i+1)
        plt.imshow(image[i])
        plt.title(title[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
    #Print answer sheet
    answer = input('Please answer here:\t')
    print(answer)
    
    #Scoring conditions
    if answer == 'C' or answer == 'c':
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        Q_3()
    
    elif answer == 'A' or answer == 'a' or answer == 'B' or answer == 'b':
        print ("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        Q_3()
    
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        Q_2()
     
    #QUESTION 3
def Q_3():
    global score
    Q3 = '''
3) Which picture below is 'Blue Cheese'?\n'''
    print(Q3)
    
    #Identify path of impages
    #path=r"C:\\Users\\DELL\\Documents\\PyGam\\"
    path=os.getcwd()
    
    #Pot Three images as multiple choices
    img_path7 = path + '\image_7.jpg'
    img_path8 = path + '\image_8.jpg'
    img_path9 = path + '\image_9.jpg'
    
    img7 = cv2.imread(img_path7,1)
    img8 = cv2.imread(img_path8,1)
    img9 = cv2.imread(img_path9,1)
    
    #Convert color of images
    img7 = cv2.cvtColor(img7, cv2.COLOR_BGR2RGB)
    img8 = cv2.cvtColor(img8, cv2.COLOR_BGR2RGB)
    img9 = cv2.cvtColor(img9, cv2.COLOR_BGR2RGB)
    
    title = ['A', 'B', 'C'] #put titles on the three pictures
    image = [img7,img8,img9]
    for i in range(3):
        plt.subplot(1,3,i+1)
        plt.imshow(image[i])
        plt.title(title[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
    #Print answer sheet
    answer = input('Please answer here:\t')
    print(answer)
    
    #Scoring conditions
    if answer == 'C' or answer == 'c':
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        round_2()
    
    elif answer == 'A' or answer == 'a' or answer == 'B' or answer == 'b':
        print ("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        round_2()
    
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        Q_3()
        
############### ROUND 2 ###############
################################################################################################################
def round_2():
    #Instruction 2
    question_number = '3'
    print(f'''\033[1m
INSTRUCTION 2:
Welcome to the second stage! In this round, you will be asked {question_number} questions with ten choices 
per question. You should select all four answers correctly in order to get the score. 
Please aware of tricks in each question. Good luck!
---3pts---\033[0m\n''')
    Q_4()
    
    #QUESTION 4
def Q_4():
    global score
    Q4 = ''' 
Which are the 4 ingredients NOT in 'Spaghetti carbonara'?\n
    1) Eggs
    2) Parmesan
    3) Bacon
    4) Black pepper
    5) Garlic
    6) Cilantro
    7) Chicken breast 
    8) Tuna
    9) Carrot
    10) Onion  
    '''
    print (Q4)
    
    #Create loop for four-time answer
    guess_list1 = []
    correct_answer = [6,7,8,9]
    print('Please key in number one-by-one with ENTER for 4 times:')
    for number in range (0,4):   
        answer = int(input('>> \t'))
        guess_list1.append(answer)
    guess_list1.sort()
    print(guess_list1)
        
    if guess_list1[:] == correct_answer[:]:
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        Q_5()
    
    elif guess_list1[:] != correct_answer[:]:
        print("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        fail()
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        round_2()  
    
    #QUESTION 5
def Q_5():
    global score
    Q5 = ''' 
Which are the 4 ingredients in 'Shrimp Tom Yum Clear Soup'?\n
    1) lemongrass
    2) galangal
    3) lime leaves
    4) Chilies
    5) Eggplants
    6) Coconut milk
    7) Green onion leaves 
    8) Cilantro
    9) Peanut
    10) Eggs

    '''
    print (Q5)
    
    #Create loop for four-time answer
    guess_list2 = []
    correct_answer = [1,2,3,4]
    print('Please type number one-by-one for 4 times:')
    for number in range (0,4):   
        answer = int(input('>> \t'))
        guess_list2.append(answer)
    guess_list2.sort()
    print(guess_list2)
    
    if guess_list2[:] == correct_answer[:]:
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        Q_6()
    
    elif guess_list2[:] != correct_answer[:]:
        print("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        fail()
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        Q_5()  
    
    
    #QUESTION 6
def Q_6():
    global score
    Q6 = ''' 
Which are the 4 ingredients in 'Blue Cheese'?\n
    1) Milk
    2) Penicillium Roqueforti
    3) Mesophilic starter i.e. Chr. Hansens R-704
    4) Rennet
    5) Sugar
    6) Black pepper
    7) Calcium chloride
    8) Oliver oil
    9) Sugar
    10) Tapioca
    '''
    print (Q6)
    
    #Create loop for four-time answer
    guess_list3 = []
    correct_answer = [1,2,3,4]
    print('Please type number one-by-one for 4 times:')
    for number in range (0,4):   
        answer = int(input('>> \t'))
        guess_list3.append(answer)
    guess_list3.sort()
    print(guess_list3)
    
    if guess_list3[:] == correct_answer[:]:
        print("> Correct!\n")
        score += 1
        input("<Press enter to continue>\n")
        round_3()
    
    elif guess_list3[:] != correct_answer[:]:
        print("> Wrong!\n")
        score -= 1
        input("<Press enter to continue>\n")
        fail()
    else:
        print ("> Error! Please try again by ENTER.\n")
        score == 0
        input("<Press enter to continue>\n")
        Q_6()  

############### ROUND 3 ###############                                    
################################################################################################################
def round_3():
    #Instruction3
    question_number3 = '2'
    print(f'''\033[1m
INSTRUCTION 3:
Within this final stage, we are going to be tested on your IQ with {question_number3} questions.
As there is no mulitiple choices for selction, you have to enter exact answer to win the game.
Let's go! 
---10pts---\033[0m\n''' )
    input("<Press enter to continue>\n")
    question_list()
    
def question_list():
    global score
    question_list = ['Supposed you buy 1kg of carrot and 1kg of tomatoes at $18 total and you know that tomatoes are twice as expensive as carrot. How much is the 1kg of carrot?',
            'Q: how many degrees Celsius are there in boiling water?',
            'Q: How many teaspoons are in a tablespoon?\n']
    
        
    #Print question
    questions = 2 #Allowing for two-time try
    while questions > 0:
        question = random.choice(question_list)
        print(question)
        print(" ")
        
    #Check answer if correct
        if question == question_list[0]:
            answer1 = input('Please answer here with a digit/number only:\t')
            print(answer1)
            
            correct_answer1 = 6
            if int(answer1) == correct_answer1:
                print('''\n correct!\n''')
                score += 5
                questions -=1
                win()
            
            else:
                print ('''\n Try again next time!\n''')
                score -= 5
                questions -=1
                fail()
                
        elif question == question_list[1]:
            answer2 = input('Please answer here with numbers only:\t')
            print(answer2)
            
            correct_answer2 = 100
            if int(answer2) == correct_answer2:
                print('''\n correct!\n''')
                score += 5
                questions -=1
                win()
            
            else:
                print ('''\n Try again next time!\n''')
                score -= 5
                questions -=1
                fail()
                
        elif question == question_list[2]:
            answer3 = input('Please answer here with a digit/number only:\t')
            print(answer3)
            
            correct_answer3 = 3
            if int(answer3) == correct_answer3:
                print('''\n correct!\n''')
                score += 5
                questions -=1
                win()
            
            else:
                print ('''\n Try again next time!\n''')
                score -= 5
                questions -=1
                fail()
            
        else:
            print ('''\n Error! Try again by ENTER.\n''')
            question_list()
        
    
        
def win():
    #Identify path of impages
    #path=r"C:\\Users\\DELL\\Documents\\PyGam\\"
    path=os.getcwd()
        
    #Pot Three images as multiple choices
    img_path10 = path + '\image_10.jpg'
    img_path11 = path + '\image_11.jpg'
    img_path12 = path + '\image_12.jpg'
    
    img10 = cv2.imread(img_path10,1)
    img11 = cv2.imread(img_path11,1)
    img12 = cv2.imread(img_path12,1)
        
    #Convert color of images
    img10 = cv2.cvtColor(img10, cv2.COLOR_BGR2RGB)
    img11 = cv2.cvtColor(img11, cv2.COLOR_BGR2RGB)
    img12 = cv2.cvtColor(img12, cv2.COLOR_BGR2RGB)
    
    
    image = [img10,img11,img12]
    
    gender_input = input ('''\nWhat is your gender?\n
                         1) Male
                         2) Female
                         3) Others\n
                         
                         Please key in a digi/number only:\t''')
    
    print('You have WON the game! Great job!')  
    if int(gender_input) == 1:
            plt.imshow(image[0])
            plt.xticks([])
            plt.yticks([])
            plt.show()
    elif int(gender_input) == 2:
            plt.imshow(image[1])
            plt.xticks([])
            plt.yticks([])
            plt.show()
    elif int(gender_input) == 3:
            plt.imshow(image[2])
            plt.xticks([])
            plt.yticks([])
            plt.show()
    
    input("<Press enter to exit, you champion!>")
    exit()
    
def fail():
    replay=input('Game over! Do you want to replay the game?\t')
    print(replay)
        
    if replay == 'Yes' or replay == 'yes' or replay == 'YES':
        print("Welcome to the game again!\n")
        input("<Press enter to continue>\n")
        round_1()
    elif replay == 'No' or replay == 'no' or replay == 'NO':
        print("Thanks for your time. Good luck!\n")
        exit()
    
start()


#########s
###### END ############### 
################################################################################################################
"""
  _ _ _______ _                 _             __                                       _   _                  _ _ _ 
 ( | )__   __| |               | |           / _|                                     | | (_)                | ( | )
  V V   | |  | |__   __ _ _ __ | | _____    | |_ ___  _ __    _   _  ___  _   _ _ __  | |_ _ _ __ ___   ___  | |V V 
        | |  | '_ \ / _` | '_ \| |/ / __|   |  _/ _ \| '__|  | | | |/ _ \| | | | '__| | __| | '_ ` _ \ / _ \ | |    
        | |  | | | | (_| | | | |   <\__ \   | || (_) | |     | |_| | (_) | |_| | |    | |_| | | | | | |  __/ |_|    
        |_|  |_| |_|\__,_|_| |_|_|\_\___/   |_| \___/|_|      \__, |\___/ \__,_|_|     \__|_|_| |_| |_|\___| (_)    
                                                               __/ |                                                
                                                              |___/                                                 
 """
# Out:
# Welcome to 'KITCHEN CONTEST GAME'!!!
# My name is Shawn, your host for today game. Before we enter to the game,
# may I know more about your?
#
# What is your name?
# s
#
# Which country are you from?
# d
#
# Which type of food do you like the most?
#                         1) American Foods
#                         2) European Foods
#                         3) Asian Foods
#
#                         Please key in a number only!
#
# 3
#
# Nice to meet you s and glad to know you are from d and like
# type #3 foods. You may be very exciting to start the game now. Have fun!!!
# <Press enter to continue>
#
# INSTRUCTION 1:
# This is the first stage of the game. You are tested on your knowledge about exotic foods
# with 3 questions. Each question has three images as choices, and you
# should select one image corresponding to the questions. Let's try!
# ---3pts---
# <Press enter to continue>
#
#
# 1) Which picture below is 'Spaghetti carbonara'?
# Please answer here:	a
# a
# > Correct!
# ...
